# %%
import pandas as pd
df = pd.read_csv('Gastritis Dataset.csv')

df.isnull().sum()
# Out:
# The_sign_of_Gastritis              0
# Time_seen_for_signs                0
# water_consumption_per_day          0
# Practices_for_the_signs            0
# Gastric_irritation_drugs           0
# Not_washing_hands_before_eating    0
# Skipped_and_delayed_meals          0
# Eating_uncooked_foods              0
# Involvement_in_Substance_Use       0
# Gastritis_symptoms                 0
# dtype: int64

# %%
df.describe()
# Out:
#        The_sign_of_Gastritis  Time_seen_for_signs  water_consumption_per_day   \
# count              364.00000           364.000000                  364.000000
# mean                 2.21978             2.296703                    1.513736
# std                  1.66177             1.681168                    0.500499
# min                  0.00000             0.000000                    1.000000
# 25%                  1.00000             1.000000                    1.000000
# 50%                  2.00000             2.000000                    2.000000
# 75%                  3.00000             4.000000                    2.000000
# max                  5.00000             5.000000                    2.000000
#
#        Practices_for_the_signs   Gastric_irritation_drugs  \
# count                364.000000                364.000000
# mean                   3.406593                  1.920330
# std                    1.083083                  0.271155
# ...
